# %%
#Data____
#Authors: Rohan, Dakota, Chris, David
#Organize/clean the raw annotated data
import numpy as np
import pandas as pd;
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# Thought process on working with the data:
#
# We have the true predicted in the annotated data set as G, the annotators broke up the by selected text in the json.
# So we decided to map selected text by policy ID further by that particular segmented ID with the class of G (10 class categorical)

# %%
#cleaning and organzing the data
filenames = ["/content/Annotations/1017_sci-news.com.csv", "/content/Annotations/1028_redorbit.com.csv","/content/Annotations/1050_honda.com.csv","/content/Annotations/105_amazon.com.csv","/content/Annotations/1106_allstate.com.csv",
             "/content/Annotations/1468_rockstargames.com.csv", "/content/Annotations/175_mlb.mlb.com.csv", "/content/Annotations/303_reddit.com.csv", "/content/Annotations/32_voxmedia.com.csv", "/content/Annotations/635_playstation.com.csv","/content/Annotations/856_sciencemag.org.csv",
             "/content/Annotations/988_solarviews.com.csv" ]

# %%
#create the dataFrames
totalData = 0
headers = ['AnnotationID', 'BATCHID', 'ANNOTATORID', 'POLICYID', 'SEGMENTID', 'categoryName','attributeValuePairs','PolicyURL','date']

# Assuming 'filenames' is a list of filenames containing your data
for i, filename in enumerate(filenames, 1):
    globals()[f'data_{i}'] = pd.read_csv(filename)
    globals()[f'data_{i}'] = pd.DataFrame(globals()[f'data_{i}'])
    globals()[f'data_{i}'] = globals()[f'data_{i}'].rename(columns=dict(zip(globals()[f'data_{i}'].columns, headers)))
    totalData += 1

#print(globals()[f'data_{1}'].head())
i = 1

# Creating a new dataframe containing all the data from all files.
newDF = pd.DataFrame()

while i <= totalData:
    print(f'The head of the {i} ')
    if isinstance(globals()[f'data_{i}'], pd.DataFrame):
        df = globals()[f'data_{i}']
        # Dropping specified columns
        columns_to_drop = ["AnnotationID", "BATCHID", "ANNOTATORID", "date"]
        df = df.drop(columns=columns_to_drop, axis=1)

        globals()[f'data_{i}'] = df
        #print(globals()[f'data_{i}'].head())

        #Adding all data to one DataFrame
        newDF = pd.concat([newDF, df], ignore_index=True)


    i += 1
# Out:
# The head of the 1
# The head of the 2
# The head of the 3
# The head of the 4
# The head of the 5
# The head of the 6
# The head of the 7
# The head of the 8
# The head of the 9
# The head of the 10
# The head of the 11
# The head of the 12

# %% [markdown]
# So Now That we have data frames for 12 urls, we want to parse the json column to extract the line that generated the categoryName.

# %%
import json

i = 1
while i <= totalData:
    selected_texts = []
    df = globals()[f'data_{i}']

    # Iterate over the rows of the dataframe
    for index, row in df.iterrows():
        attribute_pairs = json.loads(row['attributeValuePairs'])

        # Iterate over the actual json array
        for key, value in attribute_pairs.items():
            selected_text = value.get('selectedText', '')
            selected_texts.append(selected_text)
        df["ActualText"] = selected_text
        globals()[f'data{i}'] = df
    #Add the extracted selected texts to a new column named "ActualText"
    #df['ActualText'] = selected_texts

    # Update the dataframe in globals()
    globals()[f'data{i}'] = df

    # Print the "ActualText" column for debugging
    print(globals()[f'data{i}'].head())

    i += 1  # Increment i to move to the next dataframe
# Out:
#    POLICYID  SEGMENTID                categoryName  \
# 0      3905          1  First Party Collection/Use
# 1      3905          1  First Party Collection/Use
# 2      3905          2              Data Retention
# 3      3905          3  First Party Collection/Use
# 4      3905          3  First Party Collection/Use
#
#                                  attributeValuePairs      PolicyURL  \
# 0  {"Collection Mode": {"selectedText": "nformati...  Not specified
# 1  {"Collection Mode": {"selectedText": "nformati...  Not specified
# 2  {"Personal Information Type": {"selectedText":...  Not specified
# 3  {"Collection Mode": {"selectedText": "Not sele...  Not specified
# 4  {"Collection Mode": {"selectedText": "Not sele...  Not specified
#
#               ActualText
# 0  privacy@sci-news.com.
# 1  privacy@sci-news.com.
# 2  privacy@sci-news.com.
# 3  privacy@sci-news.com.
# 4  privacy@sci-news.com.
#    POLICYID  SEGMENTID                categoryName  \
# 0      3906          1                       Other
# 1      3906          2                       Other
# 2      3906          2  First Party Collection/Use
# 3      3906          3  First Party Collection/Use
# 4      3906          3  First Party Collection/Use
#
#                                  attributeValuePairs      PolicyURL  \
# 0  {"Other Type": {"selectedText": "This privacy ...  Not specified
# 1  {"Other Type": {"selectedText": "RedOrbit, Inc...  Not specified
# 2  {"Collection Mode": {"selectedText": "Not sele...  Not specified
# 3  {"Collection Mode": {"selectedText": "null", "...  Not specified
# 4  {"Collection Mode": {"selectedText": "null", "...  Not specified
#
#                                           ActualText
# 0  If users have any questions or suggestions reg...
# 1  If users have any questions or suggestions reg...
# 2  If users have any questions or suggestions reg...
# 3  If users have any questions or suggestions reg...
# 4  If users have any questions or suggestions reg...
#    POLICYID  SEGMENTID categoryName  \
# 0      3836          1        Other
# 1      3836          1        Other
# 2      3836          2        Other
# 3      3836          2        Other
# 4      3836          2        Other
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Other Type": {"selectedText": "American Hond...  12/23/14
# 1  {"Other Type": {"selectedText": "American Hond...  12/23/14
# 2  {"Other Type": {"selectedText": "This statemen...  12/23/14
# 3  {"Other Type": {"selectedText": "This statemen...  12/23/14
# 4  {"Other Type": {"selectedText": "This statemen...  12/23/14
#
#                                           ActualText
# 0  Locate a Green Dealer Green Dealers by Award L...
# 1  Locate a Green Dealer Green Dealers by Award L...
# 2  Locate a Green Dealer Green Dealers by Award L...
# 3  Locate a Green Dealer Green Dealers by Award L...
# 4  Locate a Green Dealer Green Dealers by Award L...
#    POLICYID  SEGMENTID                categoryName  \
# 0      3819          1               Policy Change
# 1      3819          1               Policy Change
# 2      3819          2                       Other
# 3      3819          2         User Choice/Control
# 4      3819          3  First Party Collection/Use
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Change Type": {"endIndexInSegment": 65, "sta...    3/3/14
# 1  {"Change Type": {"endIndexInSegment": 65, "sta...    3/3/14
# 2  {"Other Type": {"endIndexInSegment": 190, "sta...    3/3/14
# 3  {"Choice Type": {"endIndexInSegment": 280, "st...    3/3/14
# 4  {"Collection Mode": {"endIndexInSegment": 203,...    3/3/14
#
#                                           ActualText
# 0  Recommendations (including Recommended for You...
# 1  Recommendations (including Recommended for You...
# 2  Recommendations (including Recommended for You...
# 3  Recommendations (including Recommended for You...
# 4  Recommendations (including Recommended for You...
#    POLICYID  SEGMENTID   categoryName  \
# 0      3708          0  Policy Change
# 1      3708          0  Data Security
# 2      3708          0  Data Security
# 3      3708          1          Other
# 4      3708          1          Other
#
#                                  attributeValuePairs PolicyURL ActualText
# 0  {"Change Type": {"endIndexInSegment": -1, "sta...   5/29/15      share
# 1  {"Security Measure": {"endIndexInSegment": 223...   5/29/15      share
# 2  {"Security Measure": {"endIndexInSegment": 223...   5/29/15      share
# 3  {"Other Type": {"endIndexInSegment": 256, "sta...   5/29/15      share
# 4  {"Other Type": {"endIndexInSegment": 256, "sta...   5/29/15      share
#    POLICYID  SEGMENTID   categoryName  \
# 0      3723          0  Policy Change
# 1      3723          0          Other
# 2      3723          1          Other
# 3      3723          1          Other
# 4      3723          1          Other
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Change Type": {"endIndexInSegment": 31, "sta...   10/1/13
# 1  {"Other Type": {"endIndexInSegment": 31, "star...   10/1/13
# 2  {"Other Type": {"endIndexInSegment": 709, "sta...   10/1/13
# 3  {"Other Type": {"endIndexInSegment": 709, "sta...   10/1/13
# 4  {"Other Type": {"endIndexInSegment": 709, "sta...   10/1/13
#
#                                           ActualText
# 0  HOW DO I ASK A QUESTION OR FILE A COMPLAINT? F...
# 1  HOW DO I ASK A QUESTION OR FILE A COMPLAINT? F...
# 2  HOW DO I ASK A QUESTION OR FILE A COMPLAINT? F...
# 3  HOW DO I ASK A QUESTION OR FILE A COMPLAINT? F...
# 4  HOW DO I ASK A QUESTION OR FILE A COMPLAINT? F...
#    POLICYID  SEGMENTID categoryName  \
# 0      3633          0        Other
# 1      3633          0        Other
# 2      3633          1        Other
# 3      3633          1        Other
# 4      3633          1        Other
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Other Type": {"endIndexInSegment": 206, "sta...   6/30/14
# 1  {"Other Type": {"endIndexInSegment": 206, "sta...   6/30/14
# 2  {"Other Type": {"endIndexInSegment": 1069, "st...   6/30/14
# 3  {"Other Type": {"endIndexInSegment": 1605, "st...   6/30/14
# 4  {"Other Type": {"endIndexInSegment": 1069, "st...   6/30/14
#
#                                ActualText
# 0  Privacy Policy (updated June 30, 2014)
# 1  Privacy Policy (updated June 30, 2014)
# 2  Privacy Policy (updated June 30, 2014)
# 3  Privacy Policy (updated June 30, 2014)
# 4  Privacy Policy (updated June 30, 2014)
#    POLICYID  SEGMENTID categoryName  \
# 0      3621          0        Other
# 1      3621          0        Other
# 2      3621          1        Other
# 3      3621          1        Other
# 4      3621          1        Other
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Other Type": {"endIndexInSegment": 145, "sta...   4/14/15
# 1  {"Other Type": {"endIndexInSegment": 145, "sta...   4/14/15
# 2  {"Other Type": {"endIndexInSegment": 527, "sta...   4/14/15
# 3  {"Other Type": {"endIndexInSegment": 526, "sta...   4/14/15
# 4  {"Other Type": {"endIndexInSegment": 459, "sta...   4/14/15
#
#                                           ActualText
# 0  reddit welcomes questions, concerns, and feedb...
# 1  reddit welcomes questions, concerns, and feedb...
# 2  reddit welcomes questions, concerns, and feedb...
# 3  reddit welcomes questions, concerns, and feedb...
# 4  reddit welcomes questions, concerns, and feedb...
#    POLICYID  SEGMENTID   categoryName  \
# 0      3790          1  Policy Change
# 1      3790          1          Other
# 2      3790          2          Other
# 3      3790          3  Data Security
# 4      3790          3          Other
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Change Type": {"endIndexInSegment": 31, "sta...    5/1/14
# 1  {"Other Type": {"endIndexInSegment": 230, "sta...    5/1/14
# 2  {"Other Type": {"endIndexInSegment": 248, "sta...    5/1/14
# 3  {"Security Measure": {"endIndexInSegment": 429...    5/1/14
# 4  {"Other Type": {"endIndexInSegment": 829, "sta...    5/1/14
#
#                                      ActualText
# 0  contact us by email at privacy@voxmedia.com.
# 1  contact us by email at privacy@voxmedia.com.
# 2  contact us by email at privacy@voxmedia.com.
# 3  contact us by email at privacy@voxmedia.com.
# 4  contact us by email at privacy@voxmedia.com.
#    POLICYID  SEGMENTID   categoryName  \
# 0      3834          1          Other
# 1      3834          1          Other
# 2      3834          1          Other
# 3      3834          2  Data Security
# 4      3834          2  Data Security
#
#                                  attributeValuePairs PolicyURL  \
# 0  {"Other Type": {"selectedText": "If you have a...    4/1/11
# 1  {"Other Type": {"selectedText": "Sony Computer...    4/1/11
# 2  {"Other Type": {"selectedText": "If you have a...    4/1/11
# 3  {"Security Measure": {"selectedText": "To prot...    4/1/11
# 4  {"Security Measure": {"selectedText": "To prot...    4/1/11
#
#                                           ActualText
# 0  If you believe that we have not responded to y...
# 1  If you believe that we have not responded to y...
# 2  If you believe that we have not responded to y...
# 3  If you believe that we have not responded to y...
# 4  If you believe that we have not responded to y...
#    POLICYID  SEGMENTID                categoryName  \
# 0      3856          0                       Other
# 1      3856          1  First Party Collection/Use
# 2      3856          1  First Party Collection/Use
# 3      3856          2  First Party Collection/Use
# 4      3856          2  First Party Collection/Use
#
#                                  attributeValuePairs      PolicyURL  \
# 0  {"Other Type": {"selectedText": "Your data wil...  Not specified
# 1  {"Collection Mode": {"selectedText": "you know...  Not specified
# 2  {"Collection Mode": {"selectedText": "as you i...  Not specified
# 3  {"Collection Mode": {"selectedText": "null", "...  Not specified
# 4  {"Collection Mode": {"selectedText": "null", "...  Not specified
#
#                                           ActualText
# 0  American Association for the Advancement of Sc...
# 1  American Association for the Advancement of Sc...
# 2  American Association for the Advancement of Sc...
# 3  American Association for the Advancement of Sc...
# 4  American Association for the Advancement of Sc...
#    POLICYID  SEGMENTID                    categoryName  \
# 0      3835          0  Third Party Sharing/Collection
# 1      3835          0  Third Party Sharing/Collection
# 2      3835          0  Third Party Sharing/Collection
# 3      3835          0  Third Party Sharing/Collection
# 4      3835          0  Third Party Sharing/Collection
#
#                                  attributeValuePairs      PolicyURL  \
# 0  {"Third Party Entity": {"selectedText": "third...  Not specified
# 1  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2  {"Third Party Entity": {"selectedText": "third...  Not specified
# 3  {"Third Party Entity": {"selectedText": "third...  Not specified
# 4  {"Third Party Entity": {"selectedText": "third...  Not specified
#
#                                           ActualText
# 0  collect certain anonymous information when you...
# 1  collect certain anonymous information when you...
# 2  collect certain anonymous information when you...
# 3  collect certain anonymous information when you...
# 4  collect certain anonymous information when you...

# %%
#standardize the text data
for i in range(1, totalData + 1):
    if f'data_{i}' in globals() and isinstance(globals()[f'data_{i}'], pd.DataFrame):
        df = globals()[f'data_{i}']

        #remove grammar and convert to lowercase
        df['ActualText'] = df['ActualText'].apply(lambda x: x.lower().replace(',', '').replace('.', '').replace('!', '').replace('?', ''))
        globals()[f'data_{i}'] = df
    #print(globals()[f'data_{i}'].head())

# %% [markdown]
# ### Condensing all data to one dataframe

# %%
# Creating a new dataframe containing all the data from all files.
newDF = pd.DataFrame()

i = 1

while i <= totalData:
    print(f'The head of the {i} ')
    if isinstance(globals()[f'data_{i}'], pd.DataFrame):
        df = globals()[f'data_{i}']
        globals()[f'data_{i}'] = df
        #print(globals()[f'data_{i}'].head())

        #Adding all data to one DataFrame
        newDF = pd.concat([newDF, df], ignore_index=True)


    i += 1
# Out:
# The head of the 1
# The head of the 2
# The head of the 3
# The head of the 4
# The head of the 5
# The head of the 6
# The head of the 7
# The head of the 8
# The head of the 9
# The head of the 10
# The head of the 11
# The head of the 12

# %% [markdown]
# # MODEL

# %%
#!pip install transformers

# %% [markdown]
# ## Get all the imports

# %%
import transformers
import torch
from transformers import AdamW
from transformers import BertTokenizer,\
BertForSequenceClassification

import torch.nn as nn

# %% [markdown]
# ### Import Pretrained model

# %%
#import pretrained model

pretrained_model_name = 'bert-base-uncased'

# %% [markdown]
# ### Load pre-learned model

# %%
#Loading the corpus of pre-learned. By loading this pre-trained model, we are leveraging the knowledge and insights gained from its pre-training.
tokenizer = BertTokenizer.from_pretrained(pretrained_model_name)
model = BertForSequenceClassification.from_pretrained(pretrained_model_name, num_labels=10)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
newDF
# Out:
#       POLICYID  SEGMENTID                    categoryName  \
# 0         3905          1      First Party Collection/Use
# 1         3905          1      First Party Collection/Use
# 2         3905          2                  Data Retention
# 3         3905          3      First Party Collection/Use
# 4         3905          3      First Party Collection/Use
# ...        ...        ...                             ...
# 2784      3835          0  Third Party Sharing/Collection
# 2785      3835          0  Third Party Sharing/Collection
# 2786      3835          0  Third Party Sharing/Collection
# 2787      3835          0  Third Party Sharing/Collection
# 2788      3835          0  Third Party Sharing/Collection
#
#                                     attributeValuePairs      PolicyURL  \
# 0     {"Collection Mode": {"selectedText": "nformati...  Not specified
# 1     {"Collection Mode": {"selectedText": "nformati...  Not specified
# 2     {"Personal Information Type": {"selectedText":...  Not specified
# 3     {"Collection Mode": {"selectedText": "Not sele...  Not specified
# 4     {"Collection Mode": {"selectedText": "Not sele...  Not specified
# ...                                                 ...            ...
# 2784  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2785  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2786  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2787  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2788  {"Third Party Entity": {"selectedText": "third...  Not specified
#
#                                              ActualText
# 0                                   privacy@sci-newscom
# 1                                   privacy@sci-newscom
# 2                                   privacy@sci-newscom
# 3                                   privacy@sci-newscom
# 4                                   privacy@sci-newscom
# ...                                                 ...
# 2784  collect certain anonymous information when you...
# 2785  collect certain anonymous information when you...
# 2786  collect certain anonymous information when you...
# 2787  collect certain anonymous information when you...
# 2788  collect certain anonymous information when you...
#
# [2789 rows x 6 columns]

# %% [markdown]
#  ### Label encoding the data

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows
# how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'categoryName'.
newDF['categoryName']= label_encoder.fit_transform(newDF['categoryName'])

newDF['categoryName'].unique()
# Out:
# array([3, 0, 4, 5, 9, 7, 8, 6, 1, 2])

# %%
newDF
# Out:
#       POLICYID  SEGMENTID  categoryName  \
# 0         3905          1             3
# 1         3905          1             3
# 2         3905          2             0
# 3         3905          3             3
# 4         3905          3             3
# ...        ...        ...           ...
# 2784      3835          0             7
# 2785      3835          0             7
# 2786      3835          0             7
# 2787      3835          0             7
# 2788      3835          0             7
#
#                                     attributeValuePairs      PolicyURL  \
# 0     {"Collection Mode": {"selectedText": "nformati...  Not specified
# 1     {"Collection Mode": {"selectedText": "nformati...  Not specified
# 2     {"Personal Information Type": {"selectedText":...  Not specified
# 3     {"Collection Mode": {"selectedText": "Not sele...  Not specified
# 4     {"Collection Mode": {"selectedText": "Not sele...  Not specified
# ...                                                 ...            ...
# 2784  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2785  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2786  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2787  {"Third Party Entity": {"selectedText": "third...  Not specified
# 2788  {"Third Party Entity": {"selectedText": "third...  Not specified
#
#                                              ActualText
# 0                                   privacy@sci-newscom
# 1                                   privacy@sci-newscom
# 2                                   privacy@sci-newscom
# 3                                   privacy@sci-newscom
# 4                                   privacy@sci-newscom
# ...                                                 ...
# 2784  collect certain anonymous information when you...
# 2785  collect certain anonymous information when you...
# 2786  collect certain anonymous information when you...
# 2787  collect certain anonymous information when you...
# 2788  collect certain anonymous information when you...
#
# [2789 rows x 6 columns]

# %% [markdown]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
input_texts = newDF['ActualText']
labels = newDF['categoryName']

input_ids = []
attention_masks = []

for text in input_texts:
	encoded_dict = tokenizer.encode_plus(
		text,
		# add_special_tokens=True, #Whether or not to add special tokens when encoding the sequences. This will use the underlying PretrainedTokenizerBase.build_inputs_with_special_tokens function, which defines which tokens are automatically added to the input ids. This is usefull if you want to add bos or eos tokens automatically.
		# max_length=128,
		padding='max_length',  # Maximum length (in tokens) to use for padding or truncation. Has no effect if tokenize is False. If not specified, the tokenizer’s max_length attribute will be used as a default.
		# truncation=True, #  Whether to truncate sequences at the maximum length. Has no effect if tokenize is False.
		return_tensors='pt'
	)

	input_ids.append(encoded_dict['input_ids'])
	attention_masks.append(encoded_dict['attention_mask'])

# %% [markdown]
# ## Train Test Split

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer
import random

def shuffle(*args):
    # Check if all arguments have the same length
    lengths = [len(arg) for arg in args]
    if len(set(lengths)) != 1:
        raise ValueError("All arguments must have the same length.")

    # Generate a list of indices and shuffle them
    indices = list(range(lengths[0]))
    random.shuffle(indices)

    # Shuffle all input arguments based on the shuffled indices
    shuffled_args = []
    for arg in args:
        shuffled_args.append([arg[i] for i in indices])

    return tuple(shuffled_args)


# Assuming you have your input data and labels ready
#input_ids = [...]  # List of tokenized input ids
#attention_masks = [...]  # List of attention masks
#labels = [...]  # List of labels

# Shuffle the data and labels in the same order
input_ids_shuffled, attention_masks_shuffled, labels_shuffled = shuffle(input_ids, attention_masks, labels)

# Split the shuffled dataset into training and testing sets
train_input_ids, test_input_ids, train_attention_masks, test_attention_masks, train_labels, test_labels = \
    train_test_split(input_ids_shuffled, attention_masks_shuffled, labels_shuffled, test_size=0.2)
'''
# Create TensorDatasets
train_dataset = TensorDataset(torch.tensor(train_input_ids), torch.tensor(train_attention_masks), torch.tensor(train_labels))
test_dataset = TensorDataset(torch.tensor(test_input_ids), torch.tensor(test_attention_masks), torch.tensor(test_labels))

# Define batch size
batch_size = 16

# Create DataLoaders
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Now you can use train_dataloader and test_dataloader in your training and testing loops, respectively
'''


#input_ids = torch.cat(input_ids, dim=0)
#attention_masks = torch.cat(attention_masks, dim=0)
#labels = torch.tensor(labels)

train_input_ids = torch.cat(train_input_ids, dim=0)
test_input_ids = torch.cat(test_input_ids, dim=0)
train_attention_masks = torch.cat(train_attention_masks, dim=0)
test_attention_masks = torch.cat(test_attention_masks, dim=0)
train_labels = torch.tensor(train_labels)
test_labels = torch.tensor(test_labels)

# %% [markdown]
# ## Fine Tuning the model

# %%
# Define the number of classes
num_classes = newDF['categoryName'].nunique()  # Change this to the desired number of classes

# Update the model architecture to handle the increased number of classes
# Assuming model is your neural network model
# Modify the output layer to have 'num_classes' units
model.fc = nn.Linear(in_features=1, out_features=num_classes)  # Update 'in_features' according to your model's architecture

print("LENGTH: ",len(train_input_ids))

batch_size = 2
epochs = 10
optimizer = AdamW(model.parameters(), lr=2e-5)

# Define CrossEntropyLoss criterion
criterion = nn.CrossEntropyLoss()

# Fine-tuning loop with early stopping and model saving
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.train()  # The model is put into training mode using model.train().

# Define early stopping parameters
early_stopping_patience = 3
best_val_loss = float('inf')
best_model_path = "best_model.pt"
current_patience = 0

for epoch in range(epochs):  # epoch runs
    val_losses = []
    print(epoch)
    for i in range(0, train_input_ids.size(0), batch_size):  # batch runs
        batch_train_input_ids = train_input_ids[i:i+batch_size].to(device)
        batch_train_attention_masks = train_attention_masks[i:i+batch_size].to(device)
        batch_train_labels = train_labels[i:i+batch_size].to(device)

        optimizer.zero_grad()  # reset the gradient

        outputs = model(
            input_ids=batch_train_input_ids,
            attention_mask=batch_train_attention_masks
        )

        # Calculate the loss
        loss = criterion(outputs.logits, batch_train_labels)  # Accessing logits for loss calculation
        print(loss)

        val_losses.append(loss.item())

        loss.backward()
        optimizer.step()
    avg_val_loss = sum(val_losses) / len(val_losses)

    # Early stopping and model saving
    if avg_val_loss < best_val_loss:
        torch.save(model.state_dict(), best_model_path)
        best_val_loss = avg_val_loss
        current_patience = 0
    else:
        current_patience += 1
        if current_patience >= early_stopping_patience:
            print("Early stopping triggered.")
            break
# Out:
# LENGTH:  2231
# 0
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py
device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3283, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5611, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5508, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8261, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2633, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2009, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8213, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4861, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2652, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3204, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8961, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8062, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1523, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2183, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2334, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2265, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4482, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0081, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3393, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1680, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3186, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2496, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1289, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2503, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2670, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8673, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8813, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9752, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4224, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3331, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9419, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8165, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9933, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4965, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2983, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6027, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7968, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3583, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4690, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1556, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4555, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1737, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4356, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7045, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4617, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9971, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.3911, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.7723, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2187, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6122, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9715, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8744, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5666, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4411, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4321, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2661, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.4559, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5938, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.9136, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7608, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4371, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6053, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8326, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0363, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1427, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9212, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0534, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1904, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.9042, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8639, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1517, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4231, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7087, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.0037, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7604, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5381, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8571, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7227, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2922, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.1817, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6174, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.8047, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2801, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8707, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8476, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.2403, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.7602, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(0.8426, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.6313, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.8754, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(1.5787, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.0000, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.1976, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0448, device='cuda:0', grad_fn=<NllLossBackward0>)

# %% [markdown]
# ## Evaluating the model

# %%
model.to(device)
model.eval() # put the model into evaluation mode

test_input_ids = []
test_attention_masks = []

for text in test_texts:
	encoded_dict = tokenizer.encode_plus(
		text,
		# add_special_tokens=True, #Whether or not to add special tokens when encoding the sequences. This will use the underlying PretrainedTokenizerBase.build_inputs_with_special_tokens function, which defines which tokens are automatically added to the input ids. This is usefull if you want to add bos or eos tokens automatically.
		# max_length=128,
		padding='max_length',  # Maximum length (in tokens) to use for padding or truncation. Has no effect if tokenize is False. If not specified, the tokenizer’s max_length attribute will be used as a default.
		# truncation=True, #  Whether to truncate sequences at the maximum length. Has no effect if tokenize is False.
		return_tensors='pt'
	)

	test_input_ids.append(encoded_dict['input_ids'])
	test_attention_masks.append(encoded_dict['attention_mask'])

test_input_ids = torch.cat(test_input_ids, dim=0).to(device)
test_attention_masks = torch.cat(test_attention_masks, dim=0).to(device)

with torch.no_grad():
	outputs = model(
		input_ids=test_input_ids,
		attention_mask=test_attention_masks
	)

predicted_labels = torch.argmax(outputs.logits, dim=1)

# %% [markdown]
# ## Overall Predictions of the Model

# %%
for text, label in zip(test_texts, predicted_labels):
	print(f'Text: {text}\nPredicted Label: {label.item()}\n')
# Out:
# Text: POLICYID
# Predicted Label: 3
#
# Text: SEGMENTID
# Predicted Label: 3
#
# Text: categoryName
# Predicted Label: 3
#
# Text: attributeValuePairs
# Predicted Label: 3
#
# Text: PolicyURL
# Predicted Label: 3

# %% [markdown]
# ## Pre-Trained Model loading from our file:

# %%
import torch
from transformers import BertForSequenceClassification

# Instantiate the model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=10)

# Define the path to the saved model file
model_path = "best_model.pt"

# Load the model's state dictionary
state_dict = torch.load(model_path)

#print(state_dict)

# Load the state dictionary into the model
model.load_state_dict(state_dict, strict=False)

# If you want to use the model for inference, set it to evaluation mode
model.eval()


# old method that was not working model = TFBertForSequenceClassification.from_pretrained("best_model.pt", from_pt=True)
